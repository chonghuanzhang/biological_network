# %%
import os, sys
sys.path.insert(1, os.pardir)

from utilsx import *

# %%
load_pred_mol_db()
# Out:
#                                                    SMILES origin_rxn  \
# PC1     O=P(O)(O)OP(=O)(O)Nc1ncnc2c1ncn2C1OC(COP(=O)(O...     R00429
# PC2     Nc1ncnc2c1ncn2C1OC(COP(=O)(O)OP(=O)(O)OP(=O)(O...     R09394
# PC3                         Nc1ncnc2c1ncn2C1OC(CO)C(O)C1O     R01856
# PC4     Nc1ncnc2c1ncn2C1OC(COP(=O)(O)OP(=O)(O)OCC2OC(N...     R00112
# PC5     Nc1ncnc2c1ncn2C1OC(COP(=O)(O)OP(=O)(O)OCC2OC(N...     R00257
# ...                                                   ...        ...
# PC8853                         O=C(CCc1c[nH]c2ccccc12)OCl     R09570
# PC8854                          O=C(CCc1c[nH]c2ccccc12)OO     R01814
# PC8855  Cc1cc2c(cc1C)[n+]([O-])c1c(=O)[nH]c(=O)nc-1n2C...     R00548
# PC8856  Cc1cc2c(cc1CO)n(CC(O)C(O)C(O)COP(=O)(O)O)c1nc(...     R11962
# PC8857  Cc1cc2c(cc1C)[n+]([O-])c1c(=O)[nH]c(=O)nc-1n2C...     R11962
#
#        origin_mol direct
# PC1        C00002     -1
# PC2        C00002     -1
# PC3        C00002     -1
# PC4        C00004     -1
# ...

# %%
load_pred_mol_history()
# Out:
#                                                    SMILES origin_rxn  \
# PC1     O=P(O)(O)OP(=O)(O)Nc1ncnc2c1ncn2C1OC(COP(=O)(O...     R00429
# PC2     Nc1ncnc2c1ncn2C1OC(COP(=O)(O)OP(=O)(O)OP(=O)(O...     R09394
# PC3                         Nc1ncnc2c1ncn2C1OC(CO)C(O)C1O     R01856
# PC4     Nc1ncnc2c1ncn2C1OC(COP(=O)(O)OP(=O)(O)OCC2OC(N...     R00112
# PC4     Nc1ncnc2c1ncn2C1OC(COP(=O)(O)OP(=O)(O)OCC2OC(N...     R00104
# ...                                                   ...        ...
# PC1867                                   CC1OC(O)C(O)CC1O     R02438
# PC1869                OCC1OC(CC2OC(O)C(O)CC2O)C(O)C(O)C1O     R09632
# PC1869                OCC1OC(CC2OC(O)C(O)CC2O)C(O)C(O)C1O     R10098
# PC1867                                   CC1OC(O)C(O)CC1O     R08926
# PC1868                          O=P(O)(O)CC1OC(O)C(O)CC1O     R03161
#
#        origin_mol direct
# PC1        C00002     -1
# PC2        C00002     -1
# PC3        C00002     -1
# PC4        C00004     -1
# ...

# %%
load_pred_rxn_db()
# Out:
#           react    prod enzyme_name reaction_formula pred_origin direct  \
# PR1      C00002     PC1         NaN              NaN      R00429     -1
# PR2      C00002     PC2         NaN              NaN      R09394     -1
# PR3      C00002     PC3         NaN              NaN      R01856     -1
# PR4      C00004     PC4         NaN              NaN      R00112     -1
# PR5         PC5  C00004         NaN              NaN      R00257      1
# ...         ...     ...         ...              ...         ...    ...
# PR12418  PC3641  C22243         NaN              NaN      R09632      1
# PR12419  C22243  PC6659         NaN              NaN      R03161     -1
# PR12420  C22244  PC1867         NaN              NaN      R02438     -1
# PR12421  PC1869  C22244         NaN              NaN      R09632      1
# PR12422  C22244  PC1868         NaN              NaN      R03161     -1
#
#                                               react_smiles  \
# ...

# %%
load_pred_rxn_history()
# Out:
#           react    prod enzyme_name reaction_formula pred_origin direct  \
# PR1      C00002     PC1         NaN              NaN      R00429     -1
# PR2      C00002     PC2         NaN              NaN      R09394     -1
# PR3      C00002     PC3         NaN              NaN      R01856     -1
# PR4      C00004     PC4         NaN              NaN      R00112     -1
# PR4      C00004     PC4         NaN              NaN      R00104     -1
# ...         ...     ...         ...              ...         ...    ...
# PR12420  C22244  PC1867         NaN              NaN      R02438     -1
# PR12421  PC1869  C22244         NaN              NaN      R09632      1
# PR12421  PC1869  C22244         NaN              NaN      R10098      1
# PR12420  C22244  PC1867         NaN              NaN      R08926     -1
# PR12422  C22244  PC1868         NaN              NaN      R03161     -1
#
#                                               react_smiles  \
# ...
